# %% [markdown]
#    # Math behind Machine Learning
#
# <br>
# <br>
# <video controls src="data/vid.mp4", width=900, height=500 />

# %% [markdown]
# ## What is Machine Learning?
#
# ![title](data/calendar.png)
# <br>
# <br>
# <br>
#
# ## The fuel that drives machine learning
# <br>
# <video controls src="data/clip.mp4", width=900, height=500 />

# %% [markdown]
# In case, the sound is not audible from the video above, use the file located outside.

# %% [markdown]
# ## Why study mathematics for Machine Learning?
# ![title](data/math_stats.png)
#
#
# ## Importance of linear algebra
# 1. Vectors form the secret sauce
# <br>
#
# | Humidity | Temperature | Change | Climate
# |---|---|---|---
# | 20 | 27 | 1 | hot
# | 40 | 32 | 0.5 | hot and humid
# | 10 | 25 | 2 | cool and dry
# <br>
# **one hot encoding**: &nbsp;&nbsp;&nbsp;
# $$
# hot = 01 \hspace{1cm} hot\hspace{0.1cm}and\hspace{0.1cm}humid = 10 \hspace{1cm} cool\hspace{0.1cm}and\hspace{0.1cm}dry = 11 \\
# $$
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; The resultant representation would look like:
# &nbsp;&nbsp;&nbsp;&nbsp; $\begin{bmatrix}20 & 27 & 1\\
# 40 & 32 & 0.5\\
# 10 & 25 & 2\\\end{bmatrix}$
# $\begin{bmatrix}x\\
# y\\
# z\\\end{bmatrix}$ &nbsp; =  &nbsp; $\begin{bmatrix}01\\
# 10\\
# 11\\\end{bmatrix}$
#
# ### Application in real life
# ![](data/neuron.jpg)
# <br>
# ### Perceptron Algorithm
# ![](data/MLP.png)
#
# $$
# input\hspace{0.1cm} vector \hspace{0.2cm} x \hspace{0.2cm} weight\hspace{0.1cm}vector \hspace{0.2cm} = \hspace{0.2cm} net\hspace{0.1cm} or \hspace{0.1cm}summation
# $$
#
#
# $\hspace{6.3cm}\begin{bmatrix}\\
# input\hspace{0.1cm}vector\\
# \\\end{bmatrix}$
# &nbsp;&nbsp; x &nbsp;&nbsp; $\begin{bmatrix}\\
# weight\hspace{0.1cm}vector\\
# \\\end{bmatrix}$ &nbsp; =  &nbsp; $\begin{bmatrix}\\
# net\\
# \\\end{bmatrix}$
#
#
# <br>
# 2. Eigen Values and Eigen Vectors in PCA algorithm
# Elliptical dataset
# <br>
#
# ## Importance of probability
# 1) Gaussian Distribution:
# ![](data/gaussian.png)
# <br>
#   - identify intensity of colors
#   - to identify mean and variance of intensity
#   - filters
# <br>
# 3) Decision Tree:
# <br>
#
# | Outlook | Temperature | Humidity | Windy | Play
# | --- | --- | --- | --- | ---
# | Sunny | Hot | High | False | No
# | Sunny | Hot | High | True | No
# | Overcast | Hot | High | False | Yes
# | Rainy | Mild | High | False | Yes
# | Rainy | Cool | Normal | False | Yes
# | Rainy | Cool | Normal | True | No
# | Overcast | Cool | Normal | True | Yes
# | Sunny | Mild | High | False | No
# | Sunny | Cool | Normal | False | Yes
# | Rainy | Mild | Normal | False | Yes
# | Sunny | Mild | Normal | True | Yes
# | Overcast | Mild | High | True | Yes
# | Overcast | Hot | Normal | False | Yes
# | Rainy | Mild | High | True | No
#
#
#
# ![](data/DT.jpg)
# 4) Conditional Probability:
#    - Bayesian Networks and LSTM Networks
#    - Statistical Machine Translation
#    P(target_word|source_words) = ?
#
#
# ## Partial Calculus rules them all
# 1. Gradient Descent Algorithm
# <br>
# ### Error backpropagation
# ![](data/NN.png)
# <br>
# ### Optimising the model using gradient descent
# ![](data/grad.png)
